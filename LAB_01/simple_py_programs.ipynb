# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
print('Hello World')

# %%
num=10.6
type(num)

# %%
text='Hi Handsome'
type(text)

# %%
num=10
type(num)

# %%
my_friends =['Hammad', 'Sagheer', 'sarwar', 'Deepak']
print(type(my_friends))
num=10
print(type(num))
print(num)

# %%
my_friends =['Hammad', 'Sagheer', 'sarwar', 'Deepak','Saeed']
print(type(my_friends))
print(my_friends[0])
print(my_friends[1])
print(my_friends[0:3])
print(my_friends[:4])
print(my_friends[4:])
print(my_friends.index('Hammad'),my_friends.index('Deepak'))

# %%
mixed_list=['Deepak','Hammad',10,20.4]
print(type(mixed_list))
print(mixed_list[-1])
print(mixed_list[-2])
print(mixed_list[-3])
print(mixed_list[-4])

print(type(mixed_list[-1]))
print(type(mixed_list[-2]))
print(type(mixed_list[-3]))
print(type(mixed_list[-4]))

# %%
list_one=[1,2,3]
list_two=[4,5,6]
new_list=list_one+list_two
new_list

# %%
l=[]
list_one=[1,2,3]
list_two=[4,5,6]
l.append(list_one)
l.append(list_two)
l

# %%
my_friends =['Hammad', 'Sagheer', 'sarwar', 'Deepak','Saeed']
my_friends.append('Shah G')
my_friends

# %%
list_one=[1,2,3]
list_two=[4,5,6]
list_one.extend(list_two)
list_one

# %%
my_friends =['Hammad', 'Sagheer', 'sarwar', 'Deepak','Saeed']
my_friends.sort()
print(my_friends)
print(my_friends.clear())

# %%
list=[1,1,2,3,4,3,2,2,6,5,7,1,7]
print(list.count(1))
print(list.count(2))
print(list.count(7))

# %%
fruits=['Orange', 'banana','cherry']
fruits.insert(1,'apple')
fruits

# %%
fruits = ['apple', 'banana', 'cherry']

fruits.pop(0)
fruits

# %%
fruits = ['apple', 'banana', 'cherry']

fruits.reverse()
fruits

# %%
my_friends={'Deepak', 'Hammad', 'Sagheer'}
print(type(my_friends))
